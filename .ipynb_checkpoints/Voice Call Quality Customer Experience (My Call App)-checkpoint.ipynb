# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Data/November_MyCall_2022.csv")
df1 = pd.read_csv("data/December_MyCall_2022.csv")
df2 = pd.read_csv('data/January_MyCall_2023.csv')
df3 = pd.read_csv("data/February_MyCall_2023.csv")
df4 = pd.read_csv("data/March_MyCall_2023.csv")
df5 = pd.read_csv("data/April_MyCall_2023.csv")
df6 = pd.read_csv("data/March_MyCall_2023.csv")
df7 = pd.read_csv("data/June_MyCall_2023.csv")
df8 = pd.read_csv("data/July_MyCall_2023.csv")
df9 = pd.read_csv("data/August_MyCall_2023.csv")
df10 = pd.read_csv("data/September_MyCall_2023.csv")
df11 = pd.read_csv("data/October_MyCall_2023.csv")

# %%
df["month"] = "November"
df1["month"] = "December"
df2["month"] = "January"
df3["month"] = "February"
df4["month"] = "March"
df5["month"] = "April"
df6["month"] = "May"
df7["month"] = "June"
df8["month"] = "July"
df9["month"] = "August"
df10["month"] = "September"
df11["month"] = "October"

# %%
dataframes = [df , df1 , df2, df3 , df4, df5, df6 , df7 , df8, df9 , df10 , df11]

for i in dataframes:
    print(i.shape)
# Out:
# (1118, 9)
# (1370, 9)
# (660, 9)
# (577, 9)
# (1002, 9)
# (475, 9)
# (1002, 9)
# (527, 9)
# (531, 9)
# (327, 9)
# (370, 9)
# (167, 9)

# %%
data = pd.concat(dataframes)

# %%
data.head()
# Out:
#   operator inout_travelling network_type  rating calldrop_category  latitude  \
# 0       VI           Indoor           4G       5      Satisfactory      -1.0
# 1       VI           Indoor           4G       5      Satisfactory      -1.0
# 2       VI           Indoor      Unknown       5      Satisfactory      -1.0
# 3       VI           Indoor           4G       5      Satisfactory      -1.0
# 4       VI           Indoor           4G       5      Satisfactory      -1.0
#
#    longitude state_name     month
# 0       -1.0        NaN  November
# 1       -1.0        NaN  November
# 2       -1.0        NaN  November
# 3       -1.0        NaN  November
# 4       -1.0        NaN  November

# %%
data.shape
# Out:
# (8126, 9)

# %%
data.isnull().sum()
# Out:
# operator                0
# inout_travelling        0
# network_type            0
# rating                  0
# calldrop_category       0
# latitude                0
# longitude               0
# state_name           3156
# month                   0
# dtype: int64

# %%
data["year"] = data["month"].apply(lambda x: 2022 if x in ["November", "December"] else 2023)

# %%
data.head()
# Out:
#   operator inout_travelling network_type  rating calldrop_category  latitude  \
# 0       VI           Indoor           4G       5      Satisfactory      -1.0
# 1       VI           Indoor           4G       5      Satisfactory      -1.0
# 2       VI           Indoor      Unknown       5      Satisfactory      -1.0
# 3       VI           Indoor           4G       5      Satisfactory      -1.0
# 4       VI           Indoor           4G       5      Satisfactory      -1.0
#
#    longitude state_name     month  year
# 0       -1.0        NaN  November  2022
# 1       -1.0        NaN  November  2022
# 2       -1.0        NaN  November  2022
# 3       -1.0        NaN  November  2022
# 4       -1.0        NaN  November  2022

# %% [markdown]
# ### we have successfully created our data in organize form

# %% [markdown]
# - lets begin with some basic statistical analysis of our data

# %%
data.shape
# Out:
# (8126, 10)

# %%
data.columns
# Out:
# Index(['operator', 'inout_travelling', 'network_type', 'rating',
#        'calldrop_category', 'latitude', 'longitude', 'state_name', 'month',
#        'year'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8126 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   operator           8126 non-null   object
#  1   inout_travelling   8126 non-null   object
#  2   network_type       8126 non-null   object
#  3   rating             8126 non-null   int64
#  4   calldrop_category  8126 non-null   object
#  5   latitude           8126 non-null   float64
#  6   longitude          8126 non-null   float64
#  7   state_name         4970 non-null   object
#  8   month              8126 non-null   object
#  9   year               8126 non-null   int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 698.3+ KB

# %%
data.describe().T
# Out:
#             count         mean        std     min     25%          50%  \
# rating     8126.0     3.393059   1.566282     1.0     2.0     4.000000
# latitude   8126.0    11.600513  11.415273    -1.0    -1.0    12.956596
# longitude  8126.0    46.644564  38.052408    -1.1    -1.0    73.001939
# year       8126.0  2022.693822   0.460933  2022.0  2022.0  2023.000000
#
#                    75%          max
# rating        5.000000     5.000000
# latitude     19.220111    32.988897
# longitude    77.589436    91.100949
# year       2023.000000  2023.000000

# %%
data.isnull().sum()
# Out:
# operator                0
# inout_travelling        0
# network_type            0
# rating                  0
# calldrop_category       0
# latitude                0
# longitude               0
# state_name           3156
# month                   0
# year                    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 3644

# %%
data[data.duplicated()].head(30)
# Out:
#    operator inout_travelling network_type  rating   calldrop_category  \
# 1        VI           Indoor           4G       5        Satisfactory
# 3        VI           Indoor           4G       5        Satisfactory
# 4        VI           Indoor           4G       5        Satisfactory
# 5        VI           Indoor           4G       5        Satisfactory
# 6        VI           Indoor           4G       5        Satisfactory
# 7        VI           Indoor           4G       5        Satisfactory
# 8        VI           Indoor           4G       5        Satisfactory
# 9        VI           Indoor           4G       5        Satisfactory
# 10       VI           Indoor      Unknown       5        Satisfactory
# 11       VI           Indoor           4G       5        Satisfactory
# 15     RJio           Indoor           4G       1  Poor Voice Quality
# 19   Airtel           Indoor           4G       1  Poor Voice Quality
# 21   Airtel           Indoor           4G       1  Poor Voice Quality
# 23       VI           Indoor           4G       5        Satisfactory
# 24       VI           Indoor           4G       5        Satisfactory
# 25       VI           Indoor           4G       5        Satisfactory
# 26       VI           Indoor           4G       5        Satisfactory
# 27       VI           Indoor           4G       5        Satisfactory
# 28       VI           Indoor           4G       5        Satisfactory
# 29       VI           Indoor           4G       5        Satisfactory
# 30       VI           Indoor           4G       5        Satisfactory
# 31       VI           Indoor           4G       5        Satisfactory
# 32       VI           Indoor      Unknown       5        Satisfactory
# 33       VI           Indoor           4G       5        Satisfactory
# 34       VI           Indoor           4G       5        Satisfactory
# 35       VI           Indoor           4G       5        Satisfactory
# 36       VI           Indoor           4G       5        Satisfactory
# 37       VI           Indoor           4G       5        Satisfactory
# 47   Airtel           Indoor           4G       1  Poor Voice Quality
# 49     RJio           Indoor      Unknown       1  Poor Voice Quality
#
#     latitude  longitude state_name     month  year
# 1       -1.0       -1.0        NaN  November  2022
# 3       -1.0       -1.0        NaN  November  2022
# 4       -1.0       -1.0        NaN  November  2022
# 5       -1.0       -1.0        NaN  November  2022
# 6       -1.0       -1.0        NaN  November  2022
# 7       -1.0       -1.0        NaN  November  2022
# 8       -1.0       -1.0        NaN  November  2022
# 9       -1.0       -1.0        NaN  November  2022
# 10      -1.0       -1.0        NaN  November  2022
# 11      -1.0       -1.0        NaN  November  2022
# 15      -1.0       -1.0        NaN  November  2022
# 19      -1.0       -1.0        NaN  November  2022
# 21      -1.0       -1.0        NaN  November  2022
# 23      -1.0       -1.0        NaN  November  2022
# 24      -1.0       -1.0        NaN  November  2022
# 25      -1.0       -1.0        NaN  November  2022
# 26      -1.0       -1.0        NaN  November  2022
# 27      -1.0       -1.0        NaN  November  2022
# 28      -1.0       -1.0        NaN  November  2022
# 29      -1.0       -1.0        NaN  November  2022
# 30      -1.0       -1.0        NaN  November  2022
# 31      -1.0       -1.0        NaN  November  2022
# 32      -1.0       -1.0        NaN  November  2022
# 33      -1.0       -1.0        NaN  November  2022
# 34      -1.0       -1.0        NaN  November  2022
# 35      -1.0       -1.0        NaN  November  2022
# 36      -1.0       -1.0        NaN  November  2022
# 37      -1.0       -1.0        NaN  November  2022
# 47      -1.0       -1.0        NaN  November  2022
# 49      -1.0       -1.0        NaN  November  2022

# %%
data[data["month"] == "November"].head(60)
# Out:
#    operator inout_travelling network_type  rating   calldrop_category  \
# 0        VI           Indoor           4G       5        Satisfactory
# 1        VI           Indoor           4G       5        Satisfactory
# 2        VI           Indoor      Unknown       5        Satisfactory
# 3        VI           Indoor           4G       5        Satisfactory
# 4        VI           Indoor           4G       5        Satisfactory
# 5        VI           Indoor           4G       5        Satisfactory
# 6        VI           Indoor           4G       5        Satisfactory
# 7        VI           Indoor           4G       5        Satisfactory
# 8        VI           Indoor           4G       5        Satisfactory
# 9        VI           Indoor           4G       5        Satisfactory
# 10       VI           Indoor      Unknown       5        Satisfactory
# 11       VI           Indoor           4G       5        Satisfactory
# 12     RJio           Indoor           4G       5        Satisfactory
# 13   Airtel           Indoor      Unknown       5        Satisfactory
# 14     RJio           Indoor           4G       1  Poor Voice Quality
# 15     RJio           Indoor           4G       1  Poor Voice Quality
# 16       VI           Indoor           4G       1        Call Dropped
# 17     RJio           Indoor           4G       1        Call Dropped
# 18   Airtel           Indoor           4G       1  Poor Voice Quality
# 19   Airtel           Indoor           4G       1  Poor Voice Quality
# 20       VI           Indoor           4G       5        Satisfactory
# 21   Airtel           Indoor           4G       1  Poor Voice Quality
# 22       VI           Indoor           4G       5        Satisfactory
# 23       VI           Indoor           4G       5        Satisfactory
# 24       VI           Indoor           4G       5        Satisfactory
# 25       VI           Indoor           4G       5        Satisfactory
# 26       VI           Indoor           4G       5        Satisfactory
# 27       VI           Indoor           4G       5        Satisfactory
# 28       VI           Indoor           4G       5        Satisfactory
# 29       VI           Indoor           4G       5        Satisfactory
# 30       VI           Indoor           4G       5        Satisfactory
# 31       VI           Indoor           4G       5        Satisfactory
# 32       VI           Indoor      Unknown       5        Satisfactory
# 33       VI           Indoor           4G       5        Satisfactory
# 34       VI           Indoor           4G       5        Satisfactory
# 35       VI           Indoor           4G       5        Satisfactory
# 36       VI           Indoor           4G       5        Satisfactory
# 37       VI           Indoor           4G       5        Satisfactory
# 38   Airtel           Indoor           4G       1        Call Dropped
# 39   Airtel           Indoor      Unknown       5        Satisfactory
# 40   Airtel           Indoor           4G       5        Satisfactory
# 41     RJio           Indoor           4G       5        Satisfactory
# 42   Airtel          Outdoor      Unknown       1  Poor Voice Quality
# 43   Airtel           Indoor           4G       3        Satisfactory
# 44       VI           Indoor      Unknown       5        Satisfactory
# 45       VI           Indoor      Unknown       5        Satisfactory
# 46       VI           Indoor           4G       5        Satisfactory
# 47   Airtel           Indoor           4G       1  Poor Voice Quality
# 48     RJio           Indoor      Unknown       1  Poor Voice Quality
# 49     RJio           Indoor      Unknown       1  Poor Voice Quality
# 50       VI           Indoor      Unknown       1  Poor Voice Quality
# 51     RJio           Indoor      Unknown       1  Poor Voice Quality
# 52       VI           Indoor           4G       1  Poor Voice Quality
# 53   Airtel           Indoor      Unknown       5        Satisfactory
# 54   Airtel          Outdoor           4G       3        Satisfactory
# 55   Airtel           Indoor      Unknown       5        Satisfactory
